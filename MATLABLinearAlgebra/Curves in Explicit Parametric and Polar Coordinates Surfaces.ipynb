% %%
x = [1 2 5 8 4 3 4 1 2 3 2];
bar(x)

% %%
x=-2.9:0.2:2.9
bar(x,exp(-x.*x))
% Out:
% x =
%
%   Columns 1 through 7
%
%    -2.9000   -2.7000   -2.5000   -2.3000   -2.1000   -1.9000   -1.7000
%
%   Columns 8 through 14
%
%    -1.5000   -1.3000   -1.1000   -0.9000   -0.7000   -0.5000   -0.3000
%
%   Columns 15 through 21
%
%    -0.1000    0.1000    0.3000    0.5000    0.7000    0.9000    1.1000
%
%   Columns 22 through 28
%
%     1.3000    1.5000    1.7000    1.9000    2.1000    2.3000    2.5000
%
%   Columns 29 through 30
%
%     2.7000    2.9000

% %%
A = [1 6 12 5 7; 3 2 6 5 3];
bar (A, 'stacked')

% %%
bar (A, 'grouped')

% %%
barh(A,"grouped")
% Out:
% Error: The input character is not valid in MATLAB statements or expressions.

% %%
Y=randn(50)
% Out:
% Y =
%
%   Columns 1 through 7
%
%     0.5377   -0.8637    0.8404    0.5201    0.1832   -0.7342    0.0799
%     1.8339    0.0774   -0.8880   -0.0200   -1.0298   -0.0308   -0.9485
%    -2.2588   -1.2141    0.1001   -0.0348    0.9492    0.2323    0.4115
%     0.8622   -1.1135   -0.5445   -0.7982    0.3071    0.4264    0.6770
%     0.3188   -0.0068    0.3035    1.0187    0.1352   -0.3728    0.8577
%    -1.3077    1.5326   -0.6003   -0.1332    0.5152   -0.2365   -0.6912
%    -0.4336   -0.7697    0.4900   -0.7145    0.2614    2.0237    0.4494
%     0.3426    0.3714    0.7394    1.3514   -0.9415   -2.2584    0.1006
%     3.5784   -0.2256    1.7119   -0.2248   -0.1623    2.2294    0.8261
%     2.7694    1.1174   -0.1941   -0.5890   -0.1461    0.3376    0.5362
%    -1.3499   -1.0891   -2.1384   -0.2938   -0.5320    1.0001    0.8979
%     3.0349    0.0326   -0.8396   -0.8479    1.6821   -1.6642   -0.1319
%     0.7254    0.5525    1.3546   -1.1201   -0.8757   -0.5900   -0.1472
% ...

% %%
 hist(Y)
 hist(Y,8)
